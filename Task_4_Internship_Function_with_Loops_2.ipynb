# %% [markdown]
# Problem 1: Mobile Recharge Validation System

# %%
def validate_recharge(amt,valid_plans):
    if amt<50:
        return"Recharge amount must be at least ₹50."
    elif amt not in valid_plans:
        return"Invalid plan selected."
    else:
        return"Recharge Successful!"
valid_plans=[199,299,399,599]
while True:
    try:
        amt=int(input("Enter recharge amount: "))
        result=validate_recharge(amt,valid_plans)
        print(result)
        if result=="Recharge Successful!":
            break
    except ValueError:
        print("Invalid input.")
# Out:
# Enter recharge amount: 49
# Recharge amount must be at least ₹50.
# Enter recharge amount: 50
# Invalid plan selected.
# Enter recharge amount: 199
# Recharge Successful!

# %% [markdown]
# Problem 2: Inventory Reorder Alert System

# %%
def check_inventory(stock_dict):
    for product,quantity in stock_dict.items():
        if quantity<15:
            print(f"{product}: Reorder Alert!")
        else:
            print(f"{product}: Stock OK")
inventory={"Laptop":10,"Mouse":25,"Keyboard":12,"Monitor":18}
check_inventory(inventory)
# Out:
# Laptop: Reorder Alert!
# Mouse: Stock OK
# Keyboard: Reorder Alert!
# Monitor: Stock OK

# %% [markdown]
#  Problem 3: Student Result Processing System

# %%
def calculate_result(marks):
    total=0
    for mark in marks:
        total+=mark
    average=total/len(marks)
    if average>=50:
        return f"Average: {average:.2f} - Pass"
    else:
        return f"Average: {average:.2f} - Fail"
student_marks=[60,55,45,70]
print(calculate_result(student_marks))
# Out:
# Average: 57.50 - Pass

# %% [markdown]
# Problem 4: Cab Fare Estimator with Retry Option

# %%
def calculate_fare(distance,peak_hour):
    fare=50+(distance*12)
    if peak_hour.lower()=="yes":
        fare*=1.25
    return fare
while True:
    try:
        distance=float(input("Enter distance in km: "))
        peak=input("Is it peak hour? (yes/no): ")
        print(f"Total Fare: ₹{calculate_fare(distance,peak):.2f}")
        break
    except ValueError:
        print("Invalid input.")
# Out:
# Enter distance in km: 54
# Is it peak hour? (yes/no): yes
# Total Fare: ₹872.50

# %% [markdown]
# Problem 5: Employee Attendance Eligibility Checker

# %%
def check_eligibility(attendance_list):
    present_days=0
    for day in attendance_list:
        if day=="P":
            present_days+=1
    percentage=(present_days/len(attendance_list))*100
    if percentage>=75:
        return f"Attendance: {percentage:.2f}% - Eligible"
    else:
        return f"Attendance: {percentage:.2f}% - Not Eligible"
attendance=["P","P","A","P","P","A","P","P"]
print(check_eligibility(attendance))
# Out:
# Attendance: 75.00% - Eligible

# %% [markdown]
# Problem 6: Password Strength Checker

# %%
def check_password(password):
    special_chars="@#$"
    has_digit=False
    has_special=False
    if len(password)<8:
        return"Weak Password"
    for char in password:
        if char.isdigit():
            has_digit=True
        if char in special_chars:
            has_special=True
    if has_digit and has_special:
        return"Strong Password"
    else:
        return"Weak Password"
user_password=input("Enter password: ")
print(check_password(user_password))
# Out:
# Enter password: 1234@
# Weak Password
